# %%
friends = ["Long", "Huy", "Trang", "Minh", "Khoa"]
print(friends)
# Out:
# ['Long', 'Huy', 'Trang', 'Minh', 'Khoa']

# %%
animals = ["dog", "cat", "bird", "tiger", "lion"]
animals.append(4)

print(animals[0])
print(animals[-1])
print(animals[2])
# Out:
# dog
# 4
# bird

# %%
colors = ["red", "blue", "green", "yellow"]

colors.remove("blue")

colors.pop(2)

print(colors)
# Out:
# ['red', 'green']

# %%
nums = [1, 2, 2, 3, 4, 4, 5]

count_2 = nums.count(2)

print(count_2, "lần")
# Out:
# 2 lần

# %%
scores = {"An": 8, "Bình": 9, "Châu": 7}

print("Keys:", list(scores.keys()))

print("Values:", list(scores.values()))

print("Items:", list(scores.items()))
# Out:
# Keys: ['An', 'Bình', 'Châu']
# Values: [8, 9, 7]
# Items: [('An', 8), ('Bình', 9), ('Châu', 7)]

# %%
student = {
    "name": "Lan",
    "scores": {
        "math": 9,
        "english": 8,
        "history": 7
    }
}

english_score = student["scores"]["english"]
print(english_score)

scores = student["scores"].values()
average = sum(scores) / len(scores)

print(average)
# Out:
# 8
# 8.0

# %%
products = {"A": 120, "B": 80, "C": 300, "D": 50}

for key in list(products.keys()):
    if products[key] < 100:
        del products[key]

print(products)
products["E"] = 200
print(products)
print(len(products))
# Out:
# {'A': 120, 'C': 300}
# {'A': 120, 'C': 300, 'E': 200}
# 3

# %%
products = {"A": 120, "B": 80, "C": 300, "D": 50}

if "A" in products:
    print("Sản phẩm A tồn tại, giá:", products["A"])
else:
    print("Sản phẩm A đã bị xóa")


def get_value(item):
    return item[1]


sorted_products = dict(sorted(products.items(), key=get_value))

print(sorted_products)

total_value = sum(products.values())
print(total_value)

for key in list(products.keys()):
    if products[key] > 200:
        del products[key]

print(products)
# Out:
# Sản phẩm A tồn tại, giá: 120
# {'D': 50, 'B': 80, 'A': 120, 'C': 300}
# 550
# {'A': 120, 'B': 80, 'D': 50}
